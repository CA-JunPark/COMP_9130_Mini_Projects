# %% [markdown]
# # 1. Load and Inpect Data

# %% [markdown]
# # 2. Check for Missing Values

# %% [markdown]
# # 3. Visualize Distributions

# %% [markdown]
# # 4. Corrrerlation Analysis

# %% [markdown]
# # 5. Identify Potential Issues
